# %%
import random
from pathlib import Path
import os
import matplotlib.pyplot as plt
import cv2
imgdir=Path('training/training/'+'n4')
imgfile=random.choice(os.listdir(imgdir))
print(imgfile)
img=cv2.imread('training/training/'+'n4'+'/'+imgfile)
plt.imshow(img)
# Out:
# n4057.jpg
